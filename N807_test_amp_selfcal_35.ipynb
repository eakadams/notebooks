# %%
# After we have successfully calibrated the central element beam of an APERTIF observation we now also want to calibrate and image several beams
# Let's start the pipeline again as we did in the last tutorial
# Remember to change all the directory paths to your own ones
# %config IPCompleter.greedy=True
# %matplotlib notebook
import libs.lib as lib
lib.setup_logger('info', logfile='/home/adams/ipynb_apertif/log/N807_beam_35_test_amp.log')
import apercal
# Out:
# /home/apercal/pipeline/local/lib/python2.7/site-packages/pyfits/__init__.py:22: PyFITSDeprecationWarning: PyFITS is deprecated, please use astropy.io.fits
#   PyFITSDeprecationWarning)  # noqa
# root - INFO : Logging started!
# root - INFO : To see the log in a bash window use the following command:
# root - INFO : tail -n +1 -f /home/adams/ipynb_apertif/log/N807_beam_35_test_amp.log
# Setup logger with lib.setup_logger()

# %%
# The paramaters for the SELFCAL module are simplified.  I only left the standard reduction in and removed the manual and adaptive ones.
scal = apercal.scal('/home/adams/ipynb_apertif/cfg/N807_beams.cfg')
scal.show()
# Out:
# SELFCAL - INFO : ### Configuration file /home/adams/ipynb_apertif/cfg/N807_beams.cfg successfully read! ###
# SELFCAL
# 	selfcal_image_imsize = 2049
# 	selfcal_image_cellsize = 4
# 	selfcal_splitdata = True
# 	selfcal_splitdata_chunkbandwidth = 0.02
# 	selfcal_splitdata_channelbandwidth = 0.001
# 	selfcal_flagantenna =
# 	selfcal_flagline = True
# 	selfcal_flagline_sigma = 0.5
# 	selfcal_parametric = True
# 	selfcal_parametric_skymodel_radius = 0.5
# 	selfcal_parametric_skymodel_cutoff = 0.8
# 	selfcal_parametric_skymodel_distance = 30
# 	selfcal_parametric_solint = 5
# 	selfcal_parametric_uvmin = 0.5
# 	selfcal_parametric_uvmax = 1000
# 	selfcal_parametric_amp = False
# 	selfcal_standard_majorcycle = 3
# 	selfcal_standard_majorcycle_function = square
# 	selfcal_standard_minorcycle = 5
# 	selfcal_standard_minorcycle_function = square
# 	selfcal_standard_c0 = 10.0
# 	selfcal_standard_c1 = 5.0
# 	selfcal_standard_minorcycle0_dr = 3.0
# 	selfcal_standard_drinit = 25
# 	selfcal_standard_dr0 = 2.0
# 	selfcal_standard_nsigma = 45
# 	selfcal_standard_uvmin = [0.0, 0.0, 0.0]
# 	selfcal_standard_uvmax = [3000, 3000, 3000]
# 	selfcal_standard_solint = [5, 3, 0.5]
# 	selfcal_standard_amp = True
# 	selfcal_standard_amp_auto_limit = 1.0
# 	selfcal_standard_nfbin = 2

# %%
# First you might want to reduce all the beams with the same paramaters. You can easily make a list of the available beams for your dataset:
import glob
from subs import managefiles
# Move to the base directory of the data reduction
managefiles.director(scal,'ch', scal.basedir)
# Get a list of the available beams
beams = glob.glob('*')

print(beams)
# Out:
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/ #
# ['35']

# %%
# Now iterate over the list of beams and execute the self calibration
for beam in beams:
    scal.beam = beam
    scal.go()
# Out:
# SELFCAL - INFO : ########## Starting SELF CALIBRATION ##########
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal #
# SELFCAL - INFO : ### Splitting of target data into individual frequency chunks started ###
# SELFCAL - INFO : # Applying calibrator solutions to target data before averaging #
# SELFCAL - INFO : # Calibrator solutions to target data applied #
# SELFCAL - INFO : # Found 1 subband(s) in target data #
# SELFCAL - INFO : # Started splitting of subband 0 #
# SELFCAL - INFO : # Adjusting chunk size to 0.016796875 GHz for regular gridding of the data chunks over frequency #
# SELFCAL - INFO : # Starting splitting of data chunk 0 for subband 0 #
# SELFCAL - INFO : # Increasing frequency bin of data chunk 0 to keep bandwidth of chunks equal over the whole bandwidth #
# SELFCAL - INFO : # New frequency bin is 0.0010498046875 GHz #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/00 #
# SELFCAL - INFO : # Splitting of data chunk 0 for subband 0 done #
# SELFCAL - INFO : # Starting splitting of data chunk 1 for subband 0 #
# SELFCAL - INFO : # Increasing frequency bin of data chunk 1 to keep bandwidth of chunks equal over the whole bandwidth #
# SELFCAL - INFO : # New frequency bin is 0.0010498046875 GHz #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/01 #
# SELFCAL - INFO : # Splitting of data chunk 1 for subband 0 done #
# SELFCAL - INFO : # Starting splitting of data chunk 2 for subband 0 #
# SELFCAL - INFO : # Increasing frequency bin of data chunk 2 to keep bandwidth of chunks equal over the whole bandwidth #
# SELFCAL - INFO : # New frequency bin is 0.0010498046875 GHz #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/02 #
# SELFCAL - INFO : # Splitting of data chunk 2 for subband 0 done #
# SELFCAL - INFO : # Starting splitting of data chunk 3 for subband 0 #
# SELFCAL - INFO : # Increasing frequency bin of data chunk 3 to keep bandwidth of chunks equal over the whole bandwidth #
# SELFCAL - INFO : # New frequency bin is 0.0010498046875 GHz #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/03 #
# SELFCAL - INFO : # Splitting of data chunk 3 for subband 0 done #
# SELFCAL - INFO : # Starting splitting of data chunk 4 for subband 0 #
# SELFCAL - INFO : # Increasing frequency bin of data chunk 4 to keep bandwidth of chunks equal over the whole bandwidth #
# SELFCAL - INFO : # New frequency bin is 0.0010498046875 GHz #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/04 #
# SELFCAL - INFO : # Splitting of data chunk 4 for subband 0 done #
# SELFCAL - INFO : # Starting splitting of data chunk 5 for subband 0 #
# SELFCAL - INFO : # Increasing frequency bin of data chunk 5 to keep bandwidth of chunks equal over the whole bandwidth #
# SELFCAL - INFO : # New frequency bin is 0.0010498046875 GHz #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/05 #
# SELFCAL - INFO : # Splitting of data chunk 5 for subband 0 done #
# SELFCAL - INFO : # Starting splitting of data chunk 6 for subband 0 #
# SELFCAL - INFO : # Increasing frequency bin of data chunk 6 to keep bandwidth of chunks equal over the whole bandwidth #
# SELFCAL - INFO : # New frequency bin is 0.0010498046875 GHz #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/06 #
# SELFCAL - INFO : # Splitting of data chunk 6 for subband 0 done #
# SELFCAL - INFO : # Starting splitting of data chunk 7 for subband 0 #
# SELFCAL - INFO : # Increasing frequency bin of data chunk 7 to keep bandwidth of chunks equal over the whole bandwidth #
# SELFCAL - INFO : # New frequency bin is 0.0010498046875 GHz #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/07 #
# SELFCAL - INFO : # Splitting of data chunk 7 for subband 0 done #
# SELFCAL - INFO : # Splitting of data for subband 0 done #
# SELFCAL - INFO : ### Splitting of target data into individual frequency chunks done ###
# SELFCAL - INFO : ### Automatic flagging of HI-line/RFI started ###
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/00 #
# SELFCAL - INFO : # Looking through data chunk 00 #
# SELFCAL - INFO : # Found high noise in channel(s) 14 15 #
# SELFCAL - INFO : # Flagged channel(s) 14 15 in data chunk 00 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/01 #
# SELFCAL - INFO : # Looking through data chunk 01 #
# SELFCAL - INFO : # Found high noise in channel(s) 2 #
# SELFCAL - INFO : # Flagged channel(s) 2 in data chunk 01 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/02 #
# SELFCAL - INFO : # Looking through data chunk 02 #
# SELFCAL - INFO : # Found high noise in channel(s) 14 #
# SELFCAL - INFO : # Flagged channel(s) 14 in data chunk 02 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/03 #
# SELFCAL - INFO : # Looking through data chunk 03 #
# SELFCAL - INFO : # No high noise found in data chunk 03 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/04 #
# SELFCAL - INFO : # Looking through data chunk 04 #
# SELFCAL - INFO : # No high noise found in data chunk 04 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/05 #
# SELFCAL - INFO : # Looking through data chunk 05 #
# SELFCAL - INFO : # Found high noise in channel(s) 15 #
# SELFCAL - INFO : # Flagged channel(s) 15 in data chunk 05 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/06 #
# SELFCAL - INFO : # Looking through data chunk 06 #
# SELFCAL - INFO : # Found high noise in channel(s) 15 #
# SELFCAL - INFO : # Flagged channel(s) 15 in data chunk 06 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/07 #
# SELFCAL - INFO : # Looking through data chunk 07 #
# SELFCAL - INFO : # No high noise found in data chunk 07 #
# SELFCAL - INFO : ### Automatic flagging of HI-line/RFI done ###
# SELFCAL - INFO : ### Doing parametric self calibration ###
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal #
# SELFCAL - INFO : # Starting parametric self calibration routine on chunk 00 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/00 #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/00/pm #
# WARNING: AstropyDeprecationWarning: Passing a frame as a positional argument is now deprecated, use the frame= keyword argument instead. [astropy.coordinates.sky_coordinate]
# root - INFO : ### Using standard WSRT beam for calculating apparent fluxes! ###
# root - INFO : ### Field seems to have a flux of 1.960875581116352 Jy ###
# root - INFO : ### Found 2 source(s) in the model at a cutoff of 80.0 percent with a total flux of 1.7552383508209346 Jy ###
# root - INFO : ### Wrote source textfile to /data/adams/apertif/busydays/NGC807/35/selfcal/00/pm/model.txt! ###
# SELFCAL - INFO : # Creating model from textfile model.txt for chunk 00 #
# SELFCAL - INFO : # Doing parametric self-calibration on chunk 00 with solution interval 5 min and uvrange limits of 0.5~1000 klambda #
# SELFCAL - INFO : # Parametric self calibration routine on chunk 00 done! #
# SELFCAL - INFO : # Starting parametric self calibration routine on chunk 01 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/01 #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/01/pm #
# root - INFO : ### Using standard WSRT beam for calculating apparent fluxes! ###
# root - INFO : ### Field seems to have a flux of 1.9388940872866973 Jy ###
# root - INFO : ### Found 2 source(s) in the model at a cutoff of 80.0 percent with a total flux of 1.7368030051178662 Jy ###
# root - INFO : ### Wrote source textfile to /data/adams/apertif/busydays/NGC807/35/selfcal/01/pm/model.txt! ###
# SELFCAL - INFO : # Creating model from textfile model.txt for chunk 01 #
# SELFCAL - INFO : # Doing parametric self-calibration on chunk 01 with solution interval 5 min and uvrange limits of 0.5~1000 klambda #
# SELFCAL - INFO : # Parametric self calibration routine on chunk 01 done! #
# SELFCAL - INFO : # Starting parametric self calibration routine on chunk 02 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/02 #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/02/pm #
# root - INFO : ### Using standard WSRT beam for calculating apparent fluxes! ###
# root - INFO : ### Field seems to have a flux of 1.916869214487907 Jy ###
# root - INFO : ### Found 2 source(s) in the model at a cutoff of 80.0 percent with a total flux of 1.718298656951995 Jy ###
# root - INFO : ### Wrote source textfile to /data/adams/apertif/busydays/NGC807/35/selfcal/02/pm/model.txt! ###
# SELFCAL - INFO : # Creating model from textfile model.txt for chunk 02 #
# SELFCAL - INFO : # Doing parametric self-calibration on chunk 02 with solution interval 5 min and uvrange limits of 0.5~1000 klambda #
# SELFCAL - INFO : # Parametric self calibration routine on chunk 02 done! #
# SELFCAL - INFO : # Starting parametric self calibration routine on chunk 03 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/03 #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/03/pm #
# root - INFO : ### Using standard WSRT beam for calculating apparent fluxes! ###
# root - INFO : ### Field seems to have a flux of 1.894820126837564 Jy ###
# root - INFO : ### Found 2 source(s) in the model at a cutoff of 80.0 percent with a total flux of 1.699741416198759 Jy ###
# root - INFO : ### Wrote source textfile to /data/adams/apertif/busydays/NGC807/35/selfcal/03/pm/model.txt! ###
# SELFCAL - INFO : # Creating model from textfile model.txt for chunk 03 #
# SELFCAL - INFO : # Doing parametric self-calibration on chunk 03 with solution interval 5 min and uvrange limits of 0.5~1000 klambda #
# SELFCAL - INFO : # Parametric self calibration routine on chunk 03 done! #
# SELFCAL - INFO : # Starting parametric self calibration routine on chunk 04 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/04 #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/04/pm #
# root - INFO : ### Using standard WSRT beam for calculating apparent fluxes! ###
# root - INFO : ### Field seems to have a flux of 1.8727659762594318 Jy ###
# root - INFO : ### Found 2 source(s) in the model at a cutoff of 80.0 percent with a total flux of 1.6811475000884188 Jy ###
# root - INFO : ### Wrote source textfile to /data/adams/apertif/busydays/NGC807/35/selfcal/04/pm/model.txt! ###
# SELFCAL - INFO : # Creating model from textfile model.txt for chunk 04 #
# SELFCAL - INFO : # Doing parametric self-calibration on chunk 04 with solution interval 5 min and uvrange limits of 0.5~1000 klambda #
# SELFCAL - INFO : # Parametric self calibration routine on chunk 04 done! #
# SELFCAL - INFO : # Starting parametric self calibration routine on chunk 05 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/05 #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/05/pm #
# root - INFO : ### Using standard WSRT beam for calculating apparent fluxes! ###
# root - INFO : ### Field seems to have a flux of 1.8506864301974055 Jy ###
# root - INFO : ### Found 2 source(s) in the model at a cutoff of 80.0 percent with a total flux of 1.6624998661637331 Jy ###
# root - INFO : ### Wrote source textfile to /data/adams/apertif/busydays/NGC807/35/selfcal/05/pm/model.txt! ###
# SELFCAL - INFO : # Creating model from textfile model.txt for chunk 05 #
# SELFCAL - INFO : # Doing parametric self-calibration on chunk 05 with solution interval 5 min and uvrange limits of 0.5~1000 klambda #
# SELFCAL - INFO : # Parametric self calibration routine on chunk 05 done! #
# SELFCAL - INFO : # Starting parametric self calibration routine on chunk 06 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/06 #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/06/pm #
# root - INFO : ### Using standard WSRT beam for calculating apparent fluxes! ###
# root - INFO : ### Field seems to have a flux of 1.828600487235229 Jy ###
# root - INFO : ### Found 2 source(s) in the model at a cutoff of 80.0 percent with a total flux of 1.6438146610832893 Jy ###
# root - INFO : ### Wrote source textfile to /data/adams/apertif/busydays/NGC807/35/selfcal/06/pm/model.txt! ###
# SELFCAL - INFO : # Creating model from textfile model.txt for chunk 06 #
# SELFCAL - INFO : # Doing parametric self-calibration on chunk 06 with solution interval 5 min and uvrange limits of 0.5~1000 klambda #
# SELFCAL - INFO : # Parametric self calibration routine on chunk 06 done! #
# SELFCAL - INFO : # Starting parametric self calibration routine on chunk 07 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/07 #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/07/pm #
# root - INFO : ### Using standard WSRT beam for calculating apparent fluxes! ###
# root - INFO : ### Field seems to have a flux of 1.8065139412952096 Jy ###
# root - INFO : ### Found 2 source(s) in the model at a cutoff of 80.0 percent with a total flux of 1.6250969457710884 Jy ###
# root - INFO : ### Wrote source textfile to /data/adams/apertif/busydays/NGC807/35/selfcal/07/pm/model.txt! ###
# SELFCAL - INFO : # Creating model from textfile model.txt for chunk 07 #
# SELFCAL - INFO : # Doing parametric self-calibration on chunk 07 with solution interval 5 min and uvrange limits of 0.5~1000 klambda #
# SELFCAL - INFO : # Parametric self calibration routine on chunk 07 done! #
# SELFCAL - INFO : ### Parametric self calibration done ###
# SELFCAL - INFO : ### Starting standard self calibration routine ###
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal #
# SELFCAL - INFO : # Starting standard self-calibration routine on frequency chunk 00 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/00 #
# SELFCAL - INFO : # Theoretical noise for chunk 00 is 3.96e-05 Jy/beam #
# SELFCAL - INFO : # Your theoretical noise threshold will be 45 times the theoretical noise corresponding to 0.001782 Jy/beam #
# SELFCAL - INFO : # Your dynamic range limits are set to [25.0, 50.0, 100.0] for the major self-calibration cycles #
# SELFCAL - INFO : # Major self-calibration cycle 0 for frequency chunk 00 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/00/00 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 0 are [3.0, 1.5625, 6.25, 14.0625, 25.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/0 set to 0.18844391902287802 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.18844391902287802 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/0 was set to 0.037688783804575604 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.0580435 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0012523374 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/1 set to 0.36181232452392575 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.36181232452392575 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/1 was set to 0.07236246490478515 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.0733459 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0013142556 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/2 set to 0.09045308113098144 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.09045308113098144 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/2 was set to 0.018090616226196288 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.05362212 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.001189954 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/3 set to 0.04020136939154731 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.04020136939154731 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/3 was set to 0.008040273878309462 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.02206841 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0010794456 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/4 set to 0.02261327028274536 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.02261327028274536 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/4 was set to 0.004522654056549072 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.020989941 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0010616973 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 00 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=5 minutes for major cycle 00 #
# SELFCAL - INFO : # Major self-calibration cycle 0 for frequency chunk 00 finished #
# SELFCAL - INFO : # Major self-calibration cycle 1 for frequency chunk 00 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/00/01 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 1 are [25.0, 26.5625, 31.25, 39.0625, 50.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/0 set to 0.02870815396308899 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Noise threshold #
# SELFCAL - INFO : # Mask from last minor iteration of last major cycle copied #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/0 was set to 0.005741630792617798 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.020814441 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0019773124 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/1 set to 0.021615551219267004 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.021615551219267004 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/1 was set to 0.004323110243853401 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.020810386 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0019761727 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/2 set to 0.018373218536376953 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.018373218536376953 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/2 was set to 0.0036746437072753906 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.017704796 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.001970187 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/3 set to 0.014698574829101562 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.014698574829101562 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/3 was set to 0.0029397149658203126 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.014502538 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0019652862 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/4 set to 0.011483261585235596 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.011483261585235596 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/4 was set to 0.002296652317047119 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.012888102 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0019355436 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 00 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=3 minutes for major cycle 01 #
# SELFCAL - INFO : # Major self-calibration cycle 1 for frequency chunk 00 finished #
# SELFCAL - INFO : # Major self-calibration cycle 2 for frequency chunk 00 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/00/02 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 2 are [50.0, 53.125, 62.5, 78.125, 100.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/0 set to 0.019084616502126058 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Noise threshold #
# SELFCAL - INFO : # Mask from last minor iteration of last major cycle copied #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/0 was set to 0.0038169233004252115 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.008338645 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00077815534 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/1 set to 0.010777195201200598 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.010777195201200598 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/1 was set to 0.0021554390402401197 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.008338378 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00077983685 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/2 set to 0.009160615921020509 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.009160615921020509 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/2 was set to 0.0018321231842041018 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.008340327 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00077927177 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/3 set to 0.007328492736816406 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.007328492736816406 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/3 was set to 0.0014656985473632813 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.0066555873 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00077778037 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 00 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 00 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/4 set to 0.005725384950637818 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.005725384950637818 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/4 was set to 0.0011450769901275636 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.0055858027 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0007766369 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 00 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=0.5 minutes for major cycle 02 #
# SELFCAL - INFO : # Major self-calibration cycle 2 for frequency chunk 00 finished #
# SELFCAL - INFO : # Standard self-calibration routine for chunk 00 finished #
# SELFCAL - INFO : # Starting standard self-calibration routine on frequency chunk 01 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/01 #
# SELFCAL - INFO : # Theoretical noise for chunk 01 is 3.96e-05 Jy/beam #
# SELFCAL - INFO : # Your theoretical noise threshold will be 45 times the theoretical noise corresponding to 0.001782 Jy/beam #
# SELFCAL - INFO : # Your dynamic range limits are set to [25.0, 50.0, 100.0] for the major self-calibration cycles #
# SELFCAL - INFO : # Major self-calibration cycle 0 for frequency chunk 01 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/01/00 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 0 are [3.0, 1.5625, 6.25, 14.0625, 25.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/0 set to 0.18333800633748373 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.18333800633748373 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/0 was set to 0.03666760126749675 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.061218556 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0010162166 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/1 set to 0.3520089721679687 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.3520089721679687 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/1 was set to 0.07040179443359375 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.072330594 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0010693982 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/2 set to 0.08800224304199218 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.08800224304199218 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/2 was set to 0.017600448608398437 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.05587469 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0009690138 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/3 set to 0.039112108018663196 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.039112108018663196 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/3 was set to 0.00782242160373264 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.021376926 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0008513121 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/4 set to 0.022000560760498045 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.022000560760498045 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/4 was set to 0.004400112152099609 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.020493077 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00082733145 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 01 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=5 minutes for major cycle 00 #
# SELFCAL - INFO : # Major self-calibration cycle 0 for frequency chunk 01 finished #
# SELFCAL - INFO : # Major self-calibration cycle 1 for frequency chunk 01 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/01/01 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 1 are [25.0, 26.5625, 31.25, 39.0625, 50.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/0 set to 0.027815112471580507 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Noise threshold #
# SELFCAL - INFO : # Mask from last minor iteration of last major cycle copied #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/0 was set to 0.005563022494316101 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.020837339 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0015959726 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/1 set to 0.020943143508013556 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.020943143508013556 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/1 was set to 0.0041886287016027115 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.02083831 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0015947754 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/2 set to 0.017801671981811523 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.017801671981811523 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/2 was set to 0.0035603343963623046 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.016417926 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0015878675 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/3 set to 0.014241337585449218 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.014241337585449218 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/3 was set to 0.002848267517089844 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.013437883 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0015811238 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/4 set to 0.011126044988632202 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.011126044988632202 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/4 was set to 0.0022252089977264403 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.011336639 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0015736364 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 01 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=3 minutes for major cycle 01 #
# SELFCAL - INFO : # Major self-calibration cycle 1 for frequency chunk 01 finished #
# SELFCAL - INFO : # Major self-calibration cycle 2 for frequency chunk 01 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/01/02 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 2 are [50.0, 53.125, 62.5, 78.125, 100.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/0 set to 0.01842620571454366 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Noise threshold #
# SELFCAL - INFO : # Mask from last minor iteration of last major cycle copied #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/0 was set to 0.0036852411429087323 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.00871998 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0006970218 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/1 set to 0.010405386756448184 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.010405386756448184 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/1 was set to 0.002081077351289637 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.008698071 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00069660845 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/2 set to 0.008844578742980957 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.008844578742980957 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/2 was set to 0.0017689157485961914 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.008698005 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0006962742 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/3 set to 0.007075662994384765 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.007075662994384765 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/3 was set to 0.0014151325988769532 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.00607937 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00069454324 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 01 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 01 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/4 set to 0.005527861714363098 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.005527861714363098 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/4 was set to 0.0011055723428726196 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.005211819 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0006929582 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 01 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=0.5 minutes for major cycle 02 #
# SELFCAL - INFO : # Major self-calibration cycle 2 for frequency chunk 01 finished #
# SELFCAL - INFO : # Standard self-calibration routine for chunk 01 finished #
# SELFCAL - INFO : # Starting standard self-calibration routine on frequency chunk 02 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/02 #
# SELFCAL - INFO : # Theoretical noise for chunk 02 is 3.96e-05 Jy/beam #
# SELFCAL - INFO : # Your theoretical noise threshold will be 45 times the theoretical noise corresponding to 0.001782 Jy/beam #
# SELFCAL - INFO : # Your dynamic range limits are set to [25.0, 50.0, 100.0] for the major self-calibration cycles #
# SELFCAL - INFO : # Major self-calibration cycle 0 for frequency chunk 02 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/02/00 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 0 are [3.0, 1.5625, 6.25, 14.0625, 25.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 02 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/0 set to 0.1839794913927714 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.1839794913927714 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/0 was set to 0.03679589827855428 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.059317235 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0010496042 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 02 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 02 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/1 set to 0.3532406234741211 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.3532406234741211 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/1 was set to 0.07064812469482422 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.07274392 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0010993883 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 02 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 02 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/2 set to 0.08831015586853028 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.08831015586853028 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/2 was set to 0.017662031173706055 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.054133184 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0010003044 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 02 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 02 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/3 set to 0.03924895816379123 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.03924895816379123 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/3 was set to 0.007849791632758247 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.022976536 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0008868738 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 02 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 02 started #
# ...
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/4 set to 0.005380949974060059 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.005380949974060059 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/4 was set to 0.0010761899948120118 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.004639363 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0005276827 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 06 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=0.5 minutes for major cycle 02 #
# SELFCAL - INFO : # Major self-calibration cycle 2 for frequency chunk 06 finished #
# SELFCAL - INFO : # Standard self-calibration routine for chunk 06 finished #
# SELFCAL - INFO : # Starting standard self-calibration routine on frequency chunk 07 #
# SELFCAL - INFO : # Moved to directory /data/adams/apertif/busydays/NGC807/35/selfcal/07 #
# SELFCAL - INFO : # Theoretical noise for chunk 07 is 3.96e-05 Jy/beam #
# SELFCAL - INFO : # Your theoretical noise threshold will be 45 times the theoretical noise corresponding to 0.001782 Jy/beam #
# SELFCAL - INFO : # Your dynamic range limits are set to [25.0, 50.0, 100.0] for the major self-calibration cycles #
# SELFCAL - INFO : # Major self-calibration cycle 0 for frequency chunk 07 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/07/00 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 0 are [3.0, 1.5625, 6.25, 14.0625, 25.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/0 set to 0.17351057132085165 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.17351057132085165 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/0 was set to 0.03470211426417033 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.06645495 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0009332663 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/1 set to 0.33314029693603514 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.33314029693603514 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/1 was set to 0.06662805938720703 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.06314363 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00095389923 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/2 set to 0.08328507423400879 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.08328507423400879 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/2 was set to 0.01665701484680176 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.057262342 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0008756481 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/3 set to 0.03701558854844835 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.03701558854844835 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/3 was set to 0.007403117709689671 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.026104396 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00076208566 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 0/4 set to 0.020821268558502196 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.020821268558502196 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 0/4 was set to 0.00416425371170044 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 0/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 0/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 0/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.018979862 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00070433907 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 07 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=5 minutes for major cycle 00 #
# SELFCAL - INFO : # Major self-calibration cycle 0 for frequency chunk 07 finished #
# SELFCAL - INFO : # Major self-calibration cycle 1 for frequency chunk 07 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/07/01 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 1 are [25.0, 26.5625, 31.25, 39.0625, 50.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/0 set to 0.02585349678993225 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Noise threshold #
# SELFCAL - INFO : # Mask from last minor iteration of last major cycle copied #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/0 was set to 0.00517069935798645 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.01536767 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0012210977 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/1 set to 0.019466162288890164 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.019466162288890164 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/1 was set to 0.003893232457778033 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.0153482 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0012198247 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/2 set to 0.016546237945556642 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.016546237945556642 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/2 was set to 0.0033092475891113283 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.015329316 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0012189444 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/3 set to 0.013236990356445313 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.013236990356445313 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/3 was set to 0.002647398071289063 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.011306787 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0012158296 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 1/4 set to 0.0103413987159729 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.0103413987159729 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 1/4 was set to 0.0020682797431945802 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 1/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 1/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 1/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.008245882 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0012115085 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 07 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=3 minutes for major cycle 01 #
# SELFCAL - INFO : # Major self-calibration cycle 1 for frequency chunk 07 finished #
# SELFCAL - INFO : # Major self-calibration cycle 2 for frequency chunk 07 started #
# SELFCAL - INFO : # Creating directory /data/adams/apertif/busydays/NGC807/35/selfcal/07/02 #
# SELFCAL - INFO : # The minor cycle dynamic range limits for major cycle 2 are [50.0, 53.125, 62.5, 78.125, 100.0] #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/0 set to 0.01709987719853719 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Noise threshold #
# SELFCAL - INFO : # Mask from last minor iteration of last major cycle copied #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/0 was set to 0.003419975439707438 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/0 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/0 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/0 created #
# SELFCAL - INFO : # Peak of the residual image is 0.007427533 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0004995394 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 0 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/1 set to 0.009656401241526884 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.009656401241526884 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/1 was set to 0.0019312802483053768 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/1 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/1 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/1 created #
# SELFCAL - INFO : # Peak of the residual image is 0.0074709947 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.00049767067 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 1 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/2 set to 0.008207941055297851 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.008207941055297851 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/2 was set to 0.0016415882110595702 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/2 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/2 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/2 created #
# SELFCAL - INFO : # Peak of the residual image is 0.0074753044 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0004973073 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 2 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/3 set to 0.006566352844238281 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.006566352844238281 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/3 was set to 0.001313270568847656 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/3 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/3 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/3 created #
# SELFCAL - INFO : # Peak of the residual image is 0.005298959 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.0004937044 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 3 for frequency chunk 07 finished #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 07 started #
# SELFCAL - INFO : # Mask threshold for major/minor cycle 2/4 set to 0.005129963159561157 Jy/beam #
# SELFCAL - INFO : # Mask threshold set by Dynamic range threshold #
# SELFCAL - INFO : # Mask with threshold 0.005129963159561157 Jy/beam created #
# SELFCAL - INFO : # Clean threshold at major/minor cycle 2/4 was set to 0.0010259926319122314 Jy/beam #
# SELFCAL - INFO : # Major/minor cycle 2/4 cleaning done #
# SELFCAL - INFO : # Cleaned image for major/minor cycle 2/4 created #
# SELFCAL - INFO : # Residual image for major/minor cycle 2/4 created #
# SELFCAL - INFO : # Peak of the residual image is 0.0037647302 Jy/beam #
# SELFCAL - INFO : # RMS of the residual image is 0.000492049 Jy/beam #
# SELFCAL - INFO : # Minor self-calibration cycle 4 for frequency chunk 07 finished #
# SELFCAL - INFO : # Doing self-calibration with uvmin=0.0, uvmax=3000, solution interval=0.5 minutes for major cycle 02 #
# SELFCAL - INFO : # Major self-calibration cycle 2 for frequency chunk 07 finished #
# SELFCAL - INFO : # Standard self-calibration routine for chunk 07 finished #
# SELFCAL - INFO : ### Standard self calibration routine finished ###
# SELFCAL - INFO : ########## SELF CALIBRATION done ##########

# %%
# If you are satisfied with the self-calibration of all your beams, we can do the same for the continuum imaging
continuum = apercal.continuum('/home/adams/ipynb_apertif/cfg/N807_beams.cfg')
continuum.show()
continuum_image_convolbeam = 20.0,20.0,0.0
continuum.reset()
# Out:
# CONTINUUM - INFO : ### Configuration file /home/adams/ipynb_apertif/cfg/N807_beams.cfg successfully read! ###
# CONTINUUM - WARNING : ### Deleting all continuum data products. ###
# CONTINUUM
# 	continuum_image_imsize = 2049
# 	continuum_image_cellsize = 4
# 	continuum_image_centre = 02:04:55.608,+28:59:15
# 	continuum_image_restorbeam =
# 	continuum_image_convolbeam = 45.0,45.0,0.0
# 	continuum_mode = stack
# 	continuum_majorcycle_function = square
# 	continuum_minorcycle_function = square
# 	continuum_minorcycle0_dr = 3.0
# 	continuum_minorcycle = 5
# 	continuum_c0 = 10.0
# 	continuum_c1 = 5.0
# 	continuum_drinit = 25
# 	continuum_dr0 = 2.0
# 	continuum_nsigma = 45
# 	continuum_robust =
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-38c378c71773> in <module>()
#       3 continuum.show()
#       4 continuum_image_convolbeam = 20.0,20.0,0.0
# ----> 5 continuum.reset()
#
# /home/adams/apercal/modules/continuum.pyc in reset(self)
#     685         subs.setinit.setdatasetnamestomiriad(self)
#     686         self.logger.warning('### Deleting all continuum data products. ###')
# --> 687         self.director('ch', self.finaldir)
#     688         self.director('rm', self.finaldir + '/*')
#     689
#
# AttributeError: continuum instance has no attribute 'finaldir'

# %%
# Do continuum imaging for all beams by iterating with the same loop this time over the CONTINUUM module

import glob
from subs import managefiles
# Move to the base directory of the data reduction
managefiles.director(continuum,'ch', continuum.basedir)

beams = glob.glob('*')

for beam in beams:
    continuum.beam = beam
    continuum.go()
    
# You can redo the continuum imaging for individual beams in the same way as for the selfcal module above.
# This holds for all modules working on multiple beams
